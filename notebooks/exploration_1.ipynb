# %%
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv("../datasets/hotel_booking_demand.csv")
df.head(5)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
print(f"Size of the dataset: {len(df)}")
# Out:
# Size of the dataset: 119390

# %%
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(31994)

# %%
df.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cmap="viridis", cbar=False, yticklabels=False)
plt.title("Missing Data Heatmap")
plt.show()

# %% [markdown]
# Eliminar columna company, llenar columna agent con valor nulo, eliminar registros sin pais.

# %%
df['is_canceled'].value_counts(normalize=True) * 100
# Out:
# is_canceled
# 0    62.958372
# 1    37.041628
# Name: proportion, dtype: float64

# %%
df['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
df.groupby('customer_type')['is_canceled'].value_counts(normalize=True) * 100
# Out:
# customer_type    is_canceled
# Contract         0              69.038273
#                  1              30.961727
# Group            0              89.774697
#                  1              10.225303
# Transient        0              59.253680
#                  1              40.746320
# Transient-Party  0              74.570132
#                  1              25.429868
# Name: proportion, dtype: float64

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %% [markdown]
# Eliminar Undefined

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# - hotel
# La columna solo cuenta con valores validos al parecer. No necesita limpieza.
# - is_canceled
# No necesita limpieza.
# - lead time
# Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
# Mayores al promedio reemplazar por el promedio..
# - arrival_date_year
# No necesita limpieza.
# - arrival_date_month
# No necesita limpieza.
# - arrival_date_week_number
# No necesita limpieza.
# - arrival_date_day_of_month
# No necesita limpieza.
# - stays_in_week_nights
# no necesita.
# - adults
# Existen reservaciones con 0 adultos. Y reservaciones con mas de 10 adultos
# - children
# No necesita limpieza.
# - babies
# Eliminar los que tiene más de 2.
# - meal
# Eliminar undefined
# - country
# No necesita limpieza.
# - market_segment
# Eliminar undefined
# - distribution_channel
# Eliminar undefined
# - is_repeated_guest
# No necesita limpieza.
# - previous_cancellations
# Eliminar mayores a 6.
# - previous_bookings_not_canceled
# Eliminar mayores de 4
# - reserved_room_type
# No necesita limpieza
# - assigned_room_type
# No necesita limpieza
# - booking_changes
# Eliminar Mayores a 5
# - deposit_type
# No necesita limpieza.
# - agent
# Obtener la media de la frecuencia y borrar los menores a esta.
# - company
# Obtener la media de la frecuencia y borrar los menores a esta.
# - days_in_waiting_list
# Obtener la media de la frecuencia y reemplazar  los menores a esta con el promedio
# - customer_type
# No necesita limpieza.
# - adr
# Reemplazar por promedio si es menor igual a cero y esta a dos desviaciones
# estandar
# - required_car_parking_spaces
# No necesita limpieza
# - total_of_special_requests
# No necesita limpieza
# - reservation_status
# No necesita limpieza
# - reservation_status_date
# Obtener la media de la frecuencia y borrar los menores a esta.

# %%
df['reservation_status'].value_counts()
# Out:
# reservation_status
# Check-Out    75166
# Canceled     43017
# No-Show       1207
# Name: count, dtype: int64

# %%
df['reservation_status_date'].value_counts()
# Out:
# reservation_status_date
# 2015-10-21    1461
# 2015-07-06     805
# 2016-11-25     790
# 2015-01-01     763
# 2016-01-18     625
#               ...
# 2015-04-30       1
# 2015-03-13       1
# 2015-03-29       1
# 2015-04-27       1
# 2015-03-10       1
# Name: count, Length: 926, dtype: int64

# %%
df['total_of_special_requests'].value_counts()
# Out:
# total_of_special_requests
# 0    70318
# 1    33226
# 2    12969
# 3     2497
# 4      340
# 5       40
# Name: count, dtype: int64

# %%
df['required_car_parking_spaces'].value_counts()
# Out:
# required_car_parking_spaces
# 0    111974
# 1      7383
# 2        28
# 3         3
# 8         2
# Name: count, dtype: int64

# %%
df['adr'].describe()
# Out:
# count    119390.000000
# mean        101.831122
# std          50.535790
# min          -6.380000
# 25%          69.290000
# 50%          94.575000
# 75%         126.000000
# max        5400.000000
# Name: adr, dtype: float64

# %%
df['customer_type'].value_counts()
# Out:
# customer_type
# Transient          89613
# Transient-Party    25124
# Contract            4076
# Group                577
# Name: count, dtype: int64

# %%
df['days_in_waiting_list'].value_counts()
# Out:
# days_in_waiting_list
# 0      115692
# 39        227
# 58        164
# 44        141
# 31        127
#         ...
# 81          1
# 92          1
# 74          1
# 167         1
# 36          1
# Name: count, Length: 128, dtype: int64

# %%
df['company'].value_counts()
# Out:
# company
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 18.0       1
# 273.0      1
# 284.0      1
# 301.0      1
# 305.0      1
# Name: count, Length: 352, dtype: int64

# %%
df['agent'].value_counts().median()
# Out:
# np.float64(24.0)

# %%
df['deposit_type'].value_counts()
# Out:
# deposit_type
# No Deposit    104641
# Non Refund     14587
# Refundable       162
# Name: count, dtype: int64

# %%
df['booking_changes'].value_counts()
# Out:
# booking_changes
# 0     101314
# 1      12701
# 2       3805
# 3        927
# 4        376
# 5        118
# 6         63
# 7         31
# 8         17
# 9          8
# 10         6
# 14         5
# 13         5
# 15         3
# 17         2
# 16         2
# 12         2
# 11         2
# 20         1
# 21         1
# 18         1
# Name: count, dtype: int64

# %%
df['assigned_room_type'].value_counts()
# Out:
# assigned_room_type
# A    74053
# D    25322
# E     7806
# F     3751
# G     2553
# C     2375
# B     2163
# H      712
# I      363
# K      279
# P       12
# L        1
# Name: count, dtype: int64

# %%
df['reserved_room_type'].value_counts()
# Out:
# reserved_room_type
# A    85994
# D    19201
# E     6535
# F     2897
# G     2094
# B     1118
# C      932
# H      601
# P       12
# L        6
# Name: count, dtype: int64

# %%
df['previous_bookings_not_canceled'].value_counts()
# Out:
# previous_bookings_not_canceled
# 0     115770
# 1       1542
# 2        580
# 3        333
# 4        229
#        ...
# 68         1
# 69         1
# 70         1
# 71         1
# 72         1
# Name: count, Length: 73, dtype: int64

# %%
df['previous_cancellations'].value_counts()
# Out:
# previous_cancellations
# 0     112906
# 1       6051
# 2        116
# 3         65
# 24        48
# 11        35
# 4         31
# 26        26
# 25        25
# 6         22
# 5         19
# 19        19
# 14        14
# 13        12
# 21         1
# Name: count, dtype: int64

# %%
df['is_repeated_guest'].value_counts()
# Out:
# is_repeated_guest
# 0    115580
# 1      3810
# Name: count, dtype: int64

# %%
df['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97870
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
df['market_segment'].value_counts()
# Out:
# market_segment
# Online TA        56477
# Offline TA/TO    24219
# Groups           19811
# Direct           12606
# Corporate         5295
# Complementary      743
# Aviation           237
# Undefined            2
# Name: count, dtype: int64

# %%
df['hotel'].value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
df['is_canceled'].value_counts()
# Out:
# is_canceled
# 0    75166
# 1    44224
# Name: count, dtype: int64

# %%
df['arrival_date_year'].value_counts()
# Out:
# arrival_date_year
# 2016    56707
# 2017    40687
# 2015    21996
# Name: count, dtype: int64

# %%
df['arrival_date_month'].value_counts()
# Out:
# arrival_date_month
# August       13877
# July         12661
# May          11791
# October      11160
# April        11089
# June         10939
# September    10508
# March         9794
# February      8068
# November      6794
# December      6780
# January       5929
# Name: count, dtype: int64

# %%
df['arrival_date_week_number'].value_counts()
# Out:
# np.int64(53)

# %%
df['arrival_date_day_of_month'].value_counts()
# Out:
# arrival_date_day_of_month
# 17    4406
# 5     4317
# 15    4196
# 25    4160
# 26    4147
# 9     4096
# 12    4087
# 16    4078
# 2     4055
# 19    4052
# 20    4032
# 18    4002
# 24    3993
# 28    3946
# 8     3921
# 3     3855
# 30    3853
# 6     3833
# 14    3819
# 27    3802
# 21    3767
# 4     3763
# 13    3745
# 7     3665
# 1     3626
# 23    3616
# 11    3599
# 22    3596
# 29    3580
# 10    3575
# 31    2208
# Name: count, dtype: int64

# %%
def leap(year):
    if year % 4 == 0:
        if year % 100 == 0:
            if year % 400 == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

# %%
# Registers with invalid day based on the month
# Month 2 (February) has 28 days
# But also if the year is a leap year, it has 29 days
#df[(df['arrival_date_month'] == 'February') & (df['arrival_date_day_of_month'] > 28) & df['arrival_date_year'].apply(leap).apply(lambda x: not x)]
# Month 4 (April) has 30 days
#df[(df['arrival_date_month'] == 'April') & (df['arrival_date_day_of_month'] > 30)]
# Month 6 (June) has 30 days
#df[(df['arrival_date_month'] == 'June') & (df['arrival_date_day_of_month'] > 30)]
# Month 9 (September) has 30 days
#df[(df['arrival_date_month'] == 'September') & (df['arrival_date_day_of_month'] > 30)]
# Month 11 (November) has 30 days
#df[(df['arrival_date_month'] == 'November') & (df['arrival_date_day_of_month'] > 30)]
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, company, days_in_waiting_list, customer_type, adr, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date]
# Index: []
#
# [0 rows x 32 columns]

# %%
df['stays_in_weekend_nights'].describe()
# Out:
# count    119390.000000
# mean          0.927599
# std           0.998613
# min           0.000000
# 25%           0.000000
# 50%           1.000000
# 75%           2.000000
# max          19.000000
# Name: stays_in_weekend_nights, dtype: float64

# %%
df["stays_in_week_nights"].describe()
# Out:
# count    119390.000000
# mean          2.500302
# std           1.908286
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          50.000000
# Name: stays_in_week_nights, dtype: float64

# %%
df['adults'].value_counts()
# Out:
# adults
# 2     89680
# 1     23027
# 3      6202
# 0       403
# 4        62
# 26        5
# 5         2
# 27        2
# 20        2
# 40        1
# 55        1
# 50        1
# 6         1
# 10        1
# Name: count, dtype: int64

# %%
df['children'].value_counts()
# Out:
# children
# 0.0     110796
# 1.0       4861
# 2.0       3652
# 3.0         76
# 10.0         1
# Name: count, dtype: int64

# %%
df['babies'].value_counts()
# Out:
# babies
# 0     118473
# 1        900
# 2         15
# 10         1
# 9          1
# Name: count, dtype: int64

# %%
df['meal'].value_counts()
# Out:
# meal
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
#        ...
# MRT        1
# KIR        1
# SDN        1
# ATF        1
# SLE        1
# Name: count, Length: 177, dtype: int64
